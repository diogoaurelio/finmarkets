# %%
# Make sure Path is created at the root of the repository
import sys
if '../' in sys.path:
    print('path already exists')
else:
    sys.path.insert(0,'../')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import fredapi as f
from secret import akey

# %%
import matplotlib as m
from datetime import datetime
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
fred = f.Fred(api_key=akey)

# %%
df = fred.get_series('DFF') # Fetch Effective Federal Funds Rate

# %%
df.tail()
# Out:
# 2018-11-18    2.2
# 2018-11-19    2.2
# 2018-11-20    2.2
# 2018-11-21    2.2
# 2018-11-22    2.2
# dtype: float64

# %%
df['2014':'2018'].plot(figsize=(10,10),c='g')

# %%
df['2018-02':'2018-03']
# Out:
# 2018-02-01    1.42
# 2018-02-02    1.42
# 2018-02-03    1.42
# 2018-02-04    1.42
# 2018-02-05    1.42
# 2018-02-06    1.42
# 2018-02-07    1.42
# 2018-02-08    1.42
# 2018-02-09    1.42
# 2018-02-10    1.42
# 2018-02-11    1.42
# 2018-02-12    1.42
# 2018-02-13    1.42
# 2018-02-14    1.42
# 2018-02-15    1.42
# 2018-02-16    1.42
# 2018-02-17    1.42
# 2018-02-18    1.42
# 2018-02-19    1.42
# 2018-02-20    1.42
# 2018-02-21    1.42
# 2018-02-22    1.42
# 2018-02-23    1.42
# 2018-02-24    1.42
# 2018-02-25    1.42
# 2018-02-26    1.42
# 2018-02-27    1.42
# 2018-02-28    1.35
# 2018-03-01    1.42
# 2018-03-02    1.42
# 2018-03-03    1.42
# 2018-03-04    1.42
# 2018-03-05    1.42
# 2018-03-06    1.42
# 2018-03-07    1.42
# 2018-03-08    1.42
# 2018-03-09    1.42
# 2018-03-10    1.42
# 2018-03-11    1.42
# 2018-03-12    1.42
# 2018-03-13    1.42
# 2018-03-14    1.42
# 2018-03-15    1.43
# 2018-03-16    1.43
# 2018-03-17    1.43
# 2018-03-18    1.43
# 2018-03-19    1.43
# 2018-03-20    1.44
# 2018-03-21    1.44
# 2018-03-22    1.68
# 2018-03-23    1.68
# 2018-03-24    1.68
# 2018-03-25    1.68
# 2018-03-26    1.68
# 2018-03-27    1.68
# 2018-03-28    1.68
# 2018-03-29    1.68
# 2018-03-30    1.67
# 2018-03-31    1.67
# dtype: float64
